# %%
##クライアントのメニュ一覧
print('-----* Client Menu *-----')
print('d -> Spam')
print('r -> Random')
print('v -> Version')
print('---------------------------')

#イベント処理
Selected = input('Enter the Commnad here ： ')

if Selected == 'd':
  Value = int(input('Enter the Spam Value ： '))
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)
  print('Windows11 Fuck You' * Value)

  ##処理のインターバル
  input()

if Selected == 'r':
  print('')
  ##
  input()

if Selected == 'v':
  print('Version - 1.0.0.1')
  ##
  input()
# Out:
# -----* Client Menu *-----
# d -> Spam
# r -> Random
# v -> Version
# ---------------------------
# Enter the Commnad here ： d
# Enter the Spam Value ： 99999999999999
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-2-74fc3be28f2b> in <module>
#      11 if Selected == 'd':
#      12   Value = int(input('Enter the Spam Value ： '))
# ---> 13   print('Windows11 Fuck You' * Value)
#      14   print('Windows11 Fuck You' * Value)
#      15   print('Windows11 Fuck You' * Value)
#
# MemoryError:
